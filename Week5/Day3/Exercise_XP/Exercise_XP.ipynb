# %% [markdown]
# <a href="https://colab.research.google.com/github/arielwendichansky/DI_Bootcamp/blob/master/Week5/Day3/Exercise_XP/Exercise_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import math
from sklearn.metrics import roc_curve, roc_auc_score
from scipy import stats, cluster
from scipy.optimize import minimize_scalar
from scipy.stats import skew, kurtosis, median_test,ttest_ind, norm
from plotnine import (ggplot, aes, geom_point, theme_matplotlib, theme_set,labs, ggtitle,geom_col,geom_line)

# %% [markdown]
# # 🌟 Exercise 1 : Basic Scatter Plot With Plotnine

# %%
np.random.seed(42)
array1 = np.random.randint(0,20,size=20)
array2 = np.random.randint(0,20,size=20)

data = {'X':array1,
        'Y':array2}
df = pd.DataFrame(data)
df
# Out:
#      X   Y
# 0    6   9
# 1   19  15
# 2   14  14
# 3   10  14
# 4    7  18
# 5    6  11
# 6   18  19
# 7   10   2
# 8   10   4
# 9    3  18
# 10   7   6
# 11   2   8
# 12   1   6
# 13  11  17
# 14   5   3
# 15   1  13
# 16   0  17
# 17  11   8
# 18  11   1
# 19  16  19

# %%
gg = ggplot(df, aes(x='X', y='Y')) + geom_point() + theme_matplotlib()+ labs(x='X-Value', y='Y-Value') + ggtitle('Basic Scatter Plot')

print(gg)

# %% [markdown]
# # 🌟 Exercise 2 : Bar Plot Of Categorical Data With Plotnine

# %%
np.random.seed(42)

category = np.random.choice(['A','B','C'], size=30)
array1 = np.random.randint(0,21, size=30)


data = {'category':category,
        'values':array1}

df = pd.DataFrame(data)
df
# Out:
#    category  values
# 0         C       9
# 1         A      15
# 2         C      14
# 3         C      14
# 4         A      18
# 5         A      11
# 6         C      19
# 7         B       2
# 8         C       4
# 9         C      18
# 10        C       6
# 11        C      20
# 12        A       8
# 13        C       6
# 14        B      17
# 15        A       3
# 16        B      13
# 17        B      17
# 18        B       8
# 19        B      20
# 20        A       1
# 21        A      19
# 22        B      14
# 23        B       6
# 24        A      11
# 25        A       7
# 26        A      14
# 27        C       2
# 28        C      13
# 29        C      16

# %%
gg = ggplot(df, aes(x="category", y="values", fill="category")) + geom_col()+labs(x='x-axis', y='y-axis' )+ggtitle('Category Frequency')
print(gg)

# %% [markdown]
# # 🌟 Exercise 3 : Line Plot With Multiple Lines With Plotnine

# %%
np.random.seed(42)
x = np.random.randint(0,21,size=30)

y1=np.sin(x)
y2=np.cos(x)

data = {'X':x,
        'Y1':y1,
        'Y2':y2}

df = pd.DataFrame(data)
df
# Out:
#      X        Y1        Y2
# 0    6 -0.279415  0.960170
# 1   19  0.149877  0.988705
# 2   14  0.990607  0.136737
# 3   10 -0.544021 -0.839072
# 4    7  0.656987  0.753902
# 5   20  0.912945  0.408082
# 6    6 -0.279415  0.960170
# 7   18 -0.750987  0.660317
# 8   10 -0.544021 -0.839072
# 9   10 -0.544021 -0.839072
# 10  20  0.912945  0.408082
# 11   3  0.141120 -0.989992
# 12   7  0.656987  0.753902
# 13   2  0.909297 -0.416147
# 14  20  0.912945  0.408082
# 15   1  0.841471  0.540302
# 16  11 -0.999990  0.004426
# 17   5 -0.958924  0.283662
# 18   1  0.841471  0.540302
# 19  20  0.912945  0.408082
# 20   0  0.000000  1.000000
# 21  11 -0.999990  0.004426
# 22  11 -0.999990  0.004426
# 23  16 -0.287903 -0.957659
# 24   9  0.412118 -0.911130
# 25  15  0.650288 -0.759688
# 26  14  0.990607  0.136737
# 27  14  0.990607  0.136737
# 28  18 -0.750987  0.660317
# 29  11 -0.999990  0.004426

# %%
gg = ggplot(df) + aes(x='x') + geom_line(aes(y='y1'), color='blue') + geom_line(aes(y='y2'), color='red')+labs(x='x-axis', y='y-axis' )+ggtitle('Comparison of Two Functions')

print(gg)

# %% [markdown]
#  # Exercise 4 : Basic Line Chart With Plotly

# %%
data = {'months' : ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
'sales' : [200, 210, 250, 300, 320, 340, 360, 380, 390, 400, 420, 440]}

df=pd.DataFrame(data)
df
# Out:
#    months  sales
# 0     Jan    200
# 1     Feb    210
# 2     Mar    250
# 3     Apr    300
# 4     May    320
# 5     Jun    340
# 6     Jul    360
# 7     Aug    380
# 8     Sep    390
# 9     Oct    400
# 10    Nov    420
# 11    Dec    440

# %%
fig = px.line(df, x='months', y='sales', title='Monthly Sales Data')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Exercise 5 : Bar Chart With Customization With Plotly

# %%
data= {'genres':  ['Fiction', 'Non-Fiction', 'Sci-Fi', 'Mystery', 'Biography'],
'books_sold': [120, 150, 90, 80, 130]}
df=pd.DataFrame(data)
df
# Out:
#         genres  books_sold
# 0      Fiction         120
# 1  Non-Fiction         150
# 2       Sci-Fi          90
# 3      Mystery          80
# 4    Biography         130

# %%
fig = px.bar(df, x='genres', y='books_sold', color='genres', title='Books Sold by Genre')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #🌟 Exercise 6 : Scatter Plot With Size And Color Dimensions With Plotly

# %%
df = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 60000, 70000, 80000, 90000],
    'Years of Experience': [2, 5, 7, 10, 12]
})

fig = px.scatter(df, x='Age', y='Salary', size='Years of Experience',color='Years of Experience', title='Relationship between Age, Salary, and Experience')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
