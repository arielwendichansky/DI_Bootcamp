# %% [markdown]
# <a href="https://colab.research.google.com/github/arielwendichansky/DI_Bootcamp/blob/master/Week5/Day3/Exercise_XP/Exercise_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🌟 Exercise 1 : Basic Usage Of SciPy
# Import the SciPy library and explore its version.

# %%
# !pip install scipy

# !pip install numpy

# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as p
import scipy
from scipy import stats, cluster
from scipy.optimize import minimize_scalar
from scipy.stats import skew, kurtosis, median_test

# %%
scipy.info(cluster)
scipy.source(cluster)
# Out:
# ...
# Clustering package (:mod:`scipy.cluster`)
# ...
#
# .. currentmodule:: scipy.cluster
#
# .. toctree::
#    :hidden:
#
#    cluster.vq
#    cluster.hierarchy
#
# Clustering algorithms are useful in information theory, target detection,
# communications, compression, and other areas. The `vq` module only
# supports vector quantization and the k-means algorithms.
#
# The `hierarchy` module provides functions for hierarchical and
# agglomerative clustering.  Its features include generating hierarchical
# clusters from distance matrices,
# calculating statistics on clusters, cutting linkages
# to generate flat clusters, and visualizing clusters with dendrograms.
# <ipython-input-62-38055af5f16e>:1: DeprecationWarning: scipy.info is deprecated and will be removed in SciPy 2.0.0, use numpy.info instead
#   scipy.info(cluster)
# <ipython-input-62-38055af5f16e>:2: DeprecationWarning: scipy.source is deprecated and will be removed in SciPy 2.0.0, use numpy.source instead
#   scipy.source(cluster)

# %% [markdown]
# # 🌟 Exercise 2 : Descriptive Statistics
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code

# %%
data = [12, 15, 13, 12, 18, 20, 22, 21]

avg_sp = stats.tmean(data)
print('The mean is:', avg_sp)
median_np = np.median(data)
print('The median is:', median_np)
variance_sp = stats.tvar(data)
print('The variance is:', variance_sp)
std_dev_sp = stats.tstd(data)
print('The standard deviation is:', std_dev_sp)
# Out:
# The mean is: 16.625
# The median is: 16.5
# The variance is: 17.125
# The standard deviation is: 4.138236339311712

# %% [markdown]
# #🌟 Exercise 3 : Understanding Distributions
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
mean = 50
standard_deviation = 10

# Create normal distribution using the 'norm' class
# loc - specifies the mean
# scale - specifies the standard deviation
data = stats.norm( loc=mean, scale=standard_deviation)

sample = data.rvs(size=4000)
sample.round(2)

### Plot sample heights as histogram

# Use seaborn style and increase font size
sns.set_theme(style='ticks', font_scale=1.5)
# set figure dimensions
plt.figure(figsize=(12, 6))

# Plot histogram
# Use larger bin count (100) to get smoother shape
plt.hist(sample, bins=100)

plt.title("Random distribution - Histogram", pad=20)
plt.xlabel("Value", labelpad=10)
plt.ylabel("Frequency", labelpad=10)
plt.show()

# %% [markdown]
# # 🌟 Exercise 4 : T-Test Application
#
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
test_1 = np.random.normal(0.0, 1.0, 50)
test_2 = np.random.normal(0.0, 1.0, 50)

t_statistic, p_value = stats.ttest_ind(test_1, test_2)

if p_value <= 0.05 and p_value >= - 0.05:
  print("Reject the null hypothesis")
  print("t-statistic:", t_statistic)
  print("p-value:", p_value)
else:
  print("Accept the null hypothesis")
  print("t-statistic:", t_statistic)
  print("p-value:", p_value)
# Out:
# Accept the null hypothesis
# t-statistic: 0.0371024800340214
# p-value: 0.9704787679536615

# %% [markdown]
# #🌟 Exercise 5 : Working With DataFrames
#
# Task: Import a dataset using Pandas and calculate descriptive statistics for a specific column using SciPy.
#
# Sample Dataset: Use any publicly available dataset (e.g., Iris dataset).
#
# Code Example:

# %%
df = pd.read_csv('penguins.csv')
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
nobs,minmax,mean,variance,skewness,kurtosis = stats.describe(df['bill_length_mm'])
print('nobs: ',nobs,'\nminmax: ',minmax,'\nmean: ',mean, '\nvariance: ',variance,'\nskewness: ',skewness,
      '\nkurtosis: ',kurtosis)
# Out:
# nobs:  333
# minmax:  (32.1, 59.6)
# mean:  43.9927927927928
# variance:  29.90633344187561
# skewness:  0.04513597797766978
# kurtosis:  -0.8881734145880569

# %% [markdown]
# # 🌟 Exercise 6 : Advanced Statistical Functions
#
# Explore one advanced statistical function in SciPy and demonstrate its use with an example.
#
# Sample Task: Calculate kurtosis and skewness of a dataset.

# %%
# Graph using numpy.linspace()
# finding kurtosis

x1 = np.linspace( -5, 5, 1000 )
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2  )

p.plot(x1, y1, '*')


print( '\nKurtosis for normal distribution :', kurtosis(y1))

print( '\nKurtosis for normal distribution :',
      kurtosis(y1, fisher = False))

print( '\nKurtosis for normal distribution :',
      kurtosis(y1, fisher = True))
# Out:
# Kurtosis for normal distribution : -0.3073930877422071
#
# Kurtosis for normal distribution : 2.692606912257793
#
# Kurtosis for normal distribution : -0.3073930877422071

# %%
# finding Skewness

x1 = np.linspace( -5, 12, 1000 )
y1 = 1./(np.sqrt(2.*np.pi)) * np.exp( -.5*(x1)**2  )

p.plot(x1, y1, '.')

print( '\nSkewness for data : ', skew(y1))
# Out:
# Skewness for data :  1.917677776148478
